# %% [markdown]
# Data Sources
# Rental Price Data as Inferred by value of lodged bond (typically 4 weeks rent)
# Monthly Data Decemeber 2019
# https://www.fairtrading.nsw.gov.au/about-fair-trading/data-and-statistics/rental-bond-data
# RentalBond_Lodgements_December_2019.xlsx
#
# Annual 2019 Data for NSW Postcodes
# https://www.fairtrading.nsw.gov.au/about-fair-trading/data-and-statistics/rental-bond-data
# RentalBond_Lodgements_Year2019.xlsx
#
# Post Code Area Data
# https://data.mongabay.com/igapo/australia/postcodes/sydney-numeric.html
#
# Rent-Tables-Jun-Quarter-2019.xlsx

# %% [markdown]
# Postcode API
# https://postcodeapi.com.au/
# curl http://v0.postcodeapi.com.au/suburbs/3066.json -H 'Accept: application/json; indent=4'

# %%
# Install Libraries
# !conda install -c conda-forge folium --yes
# !conda install -c conda-forge wget --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda/osx-64::ca-certificates-2019.8.28-0, anaconda/osx-64::certifi-2019.9.11-py37_0, anaconda/osx-64::openssl-1.1.1d-h1de35cc_2
#   - anaconda/osx-64::ca-certificates-2019.8.28-0, anaconda/osx-64::openssl-1.1.1d-h1de35cc_2, defaults/osx-64::certifi-2019.9.11-py37_0
#   - anaconda/osx-64::ca-certificates-2019.8.28-0, anaconda/osx-64::certifi-2019.9.11-py37_0, defaults/osx-64::openssl-1.1.1d-h1de35cc_2
#   - anaconda/osx-64::ca-certificates-2019.8.28-0, defaults/osx-64::certifi-2019.9.11-py37_0, defaults/osx-64::openssl-1.1.1d-h1de35cc_2
#   - anaconda/osx-64::certifi-2019.9.11-py37_0, defaults/osx-64::ca-certificates-2019.8.28-0, defaults/osx-64::openssl-1.1.1d-h1de35cc_2
#   - defaults/osx-64::ca-certificates-2019.8.28-0, defaults/osx-64::certifi-2019.9.11-py37_0, defaults/osx-64::openssl-1.1.1d-h1de35cc_2
#   - anaconda/osx-64::certifi-2019.9.11-py37_0, anaconda/osx-64::openssl-1.1.1d-h1de35cc_2, defaults/osx-64::ca-certificates-2019.8.28-0
#   - anaconda/osx-64::openssl-1.1.1d-h1de35cc_2, defaults/osx-64::ca-certificates-2019.8.28-0, defaults/osx-64::certifi-2019.9.11-py37done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda/osx-64::ca-certificates-2019.8.28-0, anaconda/osx-64::certifi-2019.9.11-py37_0, anaconda/osx-64::openssl-1.1.1d-h1de35cc_2
#   - anaconda/osx-64::certifi-2019.9.11-py37_0, anaconda/osx-64::openssl-1.1.1d-h1de35cc_2, defaults/osx-64::ca-certificates-2019.8.28-0
#   - anaconda/osx-64::ca-certificates-2019.8.28-0, anaconda/osx-64::openssl-1.1.1d-h1de35cc_2, defaults/osx-64::certifi-2019.9.11-py37_0
#   - anaconda/osx-64::openssl-1.1.1d-h1de35cc_2, defaults/osx-64::ca-certificates-2019.8.28-0, defaults/osx-64::certifi-2019.9.11-py37_0
#   - anaconda/osx-64::ca-certificates-2019.8.28-0, defaults/osx-64::certifi-2019.9.11-py37_0, defaults/osx-64::openssl-1.1.1d-h1de35cc_2
#   - defaults/osx-64::ca-certificates-2019.8.28-0, defaults/osx-64::certifi-2019.9.11-py37_0, defaults/osx-64::openssl-1.1.1d-h1de35cc_2
#   - anaconda/osx-64::ca-certificates-2019.8.28-0, anaconda/osx-64::certifi-2019.9.11-py37_0, defaults/osx-64::openssl-1.1.1d-h1de35cc_2
#   - anaconda/osx-64::certifi-2019.9.11-py37_0, defaults/osx-64::ca-certificates-2019.8.28-0, defaults/osx-64::openssl-1.1.1d-h1de35ccdone
#
# # All requested packages already installed.

# %%
# Import Libraries
import pandas as pd
import requests
import io
from bs4 import BeautifulSoup

# %% [markdown]
# Scrape postcode data from the mongabay site and build a data frame keyed on postal code
# Note as a postcode can have many different neighbourhoods we concatenate these into a
# list to end up with a data frame of post codes and a description of the composite neighbourhoods

# %%
# Scrape Post Codes from mongabay.com
page = requests.get("https://data.mongabay.com/igapo/australia/postcodes/sydney-numeric.html")

#Get the content from the page
soup = BeautifulSoup(page.content, "html.parser")

# Post codes are in a table structure which is not identified 
# by an id or any particular CSS structure. Hence we address
# it as the tenth table on the page.
table = soup.find_all("table")[10]

# Within the table all postcodes are textually separated in a single row
# which is the third row of the table
# get the row text
text = table.find_all("td")[2].get_text()

# Convert the text to a list by splitting on newline
data = text.split("\n")

# Trim the blank first and last element which is caused by additional 
# newline markers in the data
data = data[1:len(data)-1]

# Convert postcode data to dataframe with columns of postcode and description
df_postcode = pd.DataFrame(data, columns=["data"])

# Split the data column into two seperate columns (postcode and description) on the space seperator 
df_postcode[["Postcode", "Area"]]= df_postcode["data"].str.split(" ",n=1,expand=True)

# Drop the original data columnn now we have perfromed the split 
df_postcode.drop("data", axis=1, inplace=True)

# Set Index to the PostCode column 
df_postcode = df_postcode.set_index("Postcode")

# Lastly join the data description so we have a single key for each postal district
df_postcode = df_postcode.groupby(["Postcode"])["Area"].apply(','.join).reset_index()

df_postcode.head()
# Out:
#   Postcode                                               Area
# 0     2000  Australia Square Post Office,Circular Quay,Cla...
# 1     2006                                  Sydney University
# 2     2007                                    Broadway,Ultimo
# 3     2008                             Chippendale,Darlington
# 4     2009                                            Pyrmont

# %% [markdown]
# The mongabay website is not up all of the time so I have created a local file version of the data
# The code below loads the file and performs the same transforms to create a dataframe conforming to
# the same definition as above

# %%
# Open a local postcode file
f = open("Postal Codes.csv", "r")
data = f.readlines()
f.close()

# Remove "\n" characters from the description 
data = [item.replace("\n","") for item in data]

# Convert postcode data to dataframe with columns of postcode and description
df_postcode = pd.DataFrame(data, columns=["data"])

# Split the data column into two seperate columns (postcode and description) on the space seperator 
df_postcode[["Postcode", "Area"]]= df_postcode["data"].str.split(" ",n=1,expand=True)

# Drop the original data columnn now we have perfromed the split 
df_postcode.drop("data", axis=1, inplace=True)

# Set Index to the PostCode column 
df_postcode = df_postcode.set_index("Postcode")

# Lastly join the data description so we have a single key for each postal district
df_postcode = df_postcode.groupby(["Postcode"])["Area"].apply(','.join).reset_index()

df_postcode.head()
# Out:
#   Postcode                                               Area
# 0     2000  Australia Square Post Office,Circular Quay,Cla...
# 1     2006                                  Sydney University
# 2     2007                                    Broadway,Ultimo
# 3     2008                             Chippendale,Darlington
# 4     2009                                            Pyrmont

# %%
df_rentalprice = pd.read_excel("RentalBond_Lodgements_Year_2019.xlsx", skiprows=2, header=0, sheet_name=0)
df_rentalprice.shape
# Out:
# (348925, 5)

# %%
df_rentalprice.head()
# Out:
#   Lodgement Date  Postcode Dwelling Type Bedrooms Weekly Rent
# 0     2019-03-01      2000             F        0         580
# 1     2019-03-06      2000             F        0         595
# 2     2019-03-04      2000             F        0         500
# 3     2019-03-05      2000             F        0         520
# 4     2019-03-05      2000             F        0         550

# %%
# Decode the Category Data With a Description and Add a New Column
df_rentalprice["Dwelling Type"].value_counts()
dwelling_dicts = {"F":"Flat", "H":"House", "T":"Townhouse", "U":"Unknown", "O":"Other"}
df_rentalprice["Dwelling Desc"] = df_rentalprice["Dwelling Type"].apply(lambda x: dwelling_dicts[x])

# Move the dwelling type columns next to each other
col_order = df_rentalprice.columns[0:3].to_list()
col_order = col_order + df_rentalprice.columns[-1:].to_list()
col_order = col_order + df_rentalprice.columns[3:-1].to_list()
df_rentalprice = df_rentalprice[col_order]

# Check the result
df_rentalprice.head()
# Out:
#   Lodgement Date  Postcode Dwelling Type Dwelling Desc Bedrooms Weekly Rent
# 0     2019-03-01      2000             F          Flat        0         580
# 1     2019-03-06      2000             F          Flat        0         595
# 2     2019-03-04      2000             F          Flat        0         500
# 3     2019-03-05      2000             F          Flat        0         520
# 4     2019-03-05      2000             F          Flat        0         550

# %%
# Drop Rows where the Rental Price is Unspecified = "U" as these add no useful data 
# We are only interested in the rental price
rows = df_rentalprice[df_rentalprice["Weekly Rent"]=="U"].index
df_rentalprice.drop(rows, axis=0, inplace=True)
df_rentalprice.shape

# Drop Rows where the Bedrooms is Unspecified = "U" as these add no useful data 
rows = df_rentalprice[df_rentalprice["Bedrooms"]=="U"].index
df_rentalprice.drop(rows, axis=0, inplace=True)
df_rentalprice.shape
# Out:
# (325448, 6)

# %%
# Change the Data Type of the Weekly Rent Column
df_rentalprice[["Weekly Rent"]] = df_rentalprice[["Weekly Rent"]].astype("int64")

# Change the Data Type of the Bedrooms Column
df_rentalprice[["Bedrooms"]] = df_rentalprice[["Bedrooms"]].astype("int64")

# Change the Data Type of the Postcode Column
df_rentalprice[["Postcode"]] = df_rentalprice[["Postcode"]].astype("str")

df_rentalprice.dtypes
# Out:
# Lodgement Date    datetime64[ns]
# Postcode                  object
# Dwelling Type             object
# Dwelling Desc             object
# Bedrooms                   int64
# Weekly Rent                int64
# dtype: object

# %%
# Merge the rental price data with the postcode data
# Use an inner join which will discard rows that are not listed in postcode lookuop and the rental price data
# Justification postcode lookup covers greater sydney which incorporates areas that woukd be far away
df_rentalprice = pd.merge(df_rentalprice, df_postcode, left_on="Postcode", right_on="Postcode", how="inner")
df_rentalprice.isnull().sum()
# Out:
# Lodgement Date    0
# Postcode          0
# Dwelling Type     0
# Dwelling Desc     0
# Bedrooms          0
# Weekly Rent       0
# Area              0
# dtype: int64

# %%
df_three_bed =  df_rentalprice[df_rentalprice["Bedrooms"]==3]
grps= df_three_bed.groupby("Postcode")[["Weekly Rent"]]
df_grps=grps.describe()
df_grps=df_grps["Weekly Rent"].sort_values(by="50%", ascending=False)
df_grps.head(20)
df_grps.loc[["2000","2092","2093","2094","2095","2096","2097"]]
# Out:
#           count         mean         std    min     25%     50%      75%  \
# Postcode
# 2000      269.0  1485.955390  637.489115  290.0  1100.0  1300.0  1695.00
# 2092       51.0  1020.490196  478.484331  560.0   805.0   950.0  1087.50
# 2093      150.0  1023.300000  305.466872  520.0   820.0   950.0  1100.00
# 2094       92.0  1161.032609  326.986354  670.0   942.5  1087.5  1328.75
# 2095      269.0  1319.583643  428.761603  650.0  1050.0  1200.0  1500.00
# 2096      115.0  1107.165217  331.950930  150.0   905.0  1025.0  1275.00
# 2097       91.0   884.395604  142.349014  560.0   775.0   895.0   975.00
#
#              max
# Postcode
# 2000      5000.0
# 2092      3980.0
# 2093      2350.0
# 2094      2200.0
# 2095      3454.0
# 2096      2800.0
# 2097      1250.0

# %% [markdown]
# Load the Schools Datasets
# These are obtained from the Australian Curriculum Assessment and Reporting Austhority
# School Profile : https://www.acara.edu.au/docs/default-source/default-document-library/school-profile-2018.xlsx?sfvrsn=0
# School Location: https://www.acara.edu.au/docs/default-source/default-document-library/school-locations-20189cf512404c94637ead88ff00003e0139.xlsx?sfvrsn=0

# %%
# !wget -O acara-school-profile-2018.xlsx https://www.acara.edu.au/docs/default-source/default-document-library/school-profile-2018.xlsx?sfvrsn=0
# !wget -O acara-school-locs-2018.xlsx https://www.acara.edu.au/docs/default-source/default-document-library/school-locations-20189cf512404c94637ead88ff00003e0139.xlsx?sfvrsn=0
# Out:
# --2020-01-29 18:52:20--  https://www.acara.edu.au/docs/default-source/default-document-library/school-profile-2018.xlsx?sfvrsn=0
# Resolving www.acara.edu.au (www.acara.edu.au)... 2606:4700:10::6814:ed18, 2606:4700:10::6814:ec18, 104.20.237.24, ...
# Connecting to www.acara.edu.au (www.acara.edu.au)|2606:4700:10::6814:ed18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1696292 (1.6M) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘acara-school-profile-2018.xlsx’
#
# acara-school-profil 100%[===================>]   1.62M  2.86MB/s    in 0.6s
#
# 2020-01-29 18:52:20 (2.86 MB/s) - ‘acara-school-profile-2018.xlsx’ saved [1696292/1696292]
#
# --2020-01-29 18:52:21--  https://www.acara.edu.au/docs/default-source/default-document-library/school-locations-20189cf512404c94637ead88ff00003e0139.xlsx?sfvrsn=0
# Resolving www.acara.edu.au (www.acara.edu.au)... 2606:4700:10::6814:ed18, 2606:4700:10::6814:ec18, 104.20.237.24, ...
# Connecting to www.acara.edu.au (www.acara.edu.au)|2606:4700:10::6814:ed18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1461433 (1.4M) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘acara-school-locs-2018.xlsx’
#
# acara-school-locs-2 100%[===================>]   1.39M  2.86MB/s    in 0.5s
#
# 2020-01-29 18:52:21 (2.86 MB/s) - ‘acara-school-locs-2018.xlsx’ saved [1461433/1461433]

# %%
# Read the School Profile Data Into a dataframe
df_schools = pd.read_excel("acara-school-profile-2018.xlsx", sheet_name=1)
df_schools.head()
# Out:
#    Calendar Year  ACARA SML ID  AGE ID  \
# 0           2018         40000     3.0
# 1           2018         40001     4.0
# 2           2018         40002     5.0
# 3           2018         40003     7.0
# 4           2018         40004     9.0
#
#                                 School Name        Suburb State  Postcode  \
# 0            Corpus Christi Catholic School     Bellerive   TAS      7018
# 1                              Fahan School     Sandy Bay   TAS      7005
# 2                  Geneva Christian College       Latrobe   TAS      7307
# 3               Holy Rosary Catholic School     Claremont   TAS      7011
# 4  Immaculate Heart of Mary Catholic School  Lenah Valley   TAS      7008
#
#   School Sector School Type           Campus Type  ... Teaching Staff  \
# 0      Catholic     Primary  School Single Entity  ...           29.0
# 1   Independent    Combined  School Single Entity  ...           41.0
# 2   Independent    Combined  School Single Entity  ...           23.0
# 3      Catholic     Primary  School Single Entity  ...           28.0
# 4      Catholic     Primary  School Single Entity  ...           15.0
#
#   Full Time Equivalent Teaching Staff Non-Teaching Staff  \
# 0                                20.8               18.0
# 1                                35.0               27.0
# 2                                16.0               29.0
# 3                                23.5               24.0
# 4                                11.3               10.0
#
#   Full Time Equivalent Non-Teaching Staff Total Enrolments Girls Enrolments  \
# 0                                    10.3            380.0            179.0
# 1                                    19.0            390.0            390.0
# 2                                    15.6            208.0             89.0
# 3                                    11.3            399.0            176.0
# 4                                     4.8            200.0            107.0
#
#    Boys Enrolments  Full Time Equivalent Enrolments  \
# 0            201.0                            380.0
# 1              0.0                            390.0
# 2            119.0                            208.0
# 3            223.0                            399.0
# 4             93.0                            200.0
#
#    Indigenous Enrolments (%)  Language Background Other Than English (%)
# 0                        2.0                                         3.0
# 1                        1.0                                         7.0
# 2                        6.0                                         5.0
# 3                        5.0                                         1.0
# 4                       11.0                                        15.0
#
# [5 rows x 31 columns]

# %%
# Read the school locations data into a dataframe
df_school_locs = pd.read_excel("acara-school-locs-2018.xlsx", sheet_name=1)
df_school_locs.head()
# Out:
#    Calendar Year  ACARA SML ID  AGE ID  \
# 0           2018         40000     3.0
# 1           2018         40001     4.0
# 2           2018         40002     5.0
# 3           2018         40003     7.0
# 4           2018         40004     9.0
#
#                                 School Name        Suburb State  Postcode  \
# 0            Corpus Christi Catholic School     BELLERIVE   TAS      7018
# 1                              Fahan School     SANDY BAY   TAS      7005
# 2                  Geneva Christian College       LATROBE   TAS      7307
# 3               Holy Rosary Catholic School     CLAREMONT   TAS      7011
# 4  Immaculate Heart of Mary Catholic School  LENAH VALLEY   TAS      7008
#
#   School Sector School Type           Campus Type  ...   Latitude   Longitude  \
# 0      Catholic     Primary  School Single Entity  ... -42.871256  147.371473
# 1   Independent    Combined  School Single Entity  ... -42.916158  147.352764
# 2   Independent    Combined  School Single Entity  ... -41.226741  146.438726
# 3      Catholic     Primary  School Single Entity  ... -42.789375  147.248306
# 4      Catholic     Primary  School Single Entity  ... -42.865543  147.290159
#
#    Statistical Area 1  Statistical Area 2   Name of Statistical Area 2  \
# 0             6100410               61004            Bellerive - Rosny
# 1             6103105               61031                    Sandy Bay
# 2             6108720               61087                      Latrobe
# 3             6101510               61015             Claremont (Tas.)
# 4             6102812               61028  Lenah Valley - Mount Stuart
#
#   Statistical Area 3  Name of Statistical Area 3 Statistical Area 4  \
# 0              60102         Hobart - North East                601
# 1              60105                Hobart Inner                601
# 2              60402                   Devonport                604
# 3              60103         Hobart - North West                601
# 4              60105                Hobart Inner                601
#
#    Name of Statistical Area 4       ABS Remoteness Area
# 0                      Hobart  Inner Regional Australia
# 1                      Hobart  Inner Regional Australia
# 2         West and North West  Outer Regional Australia
# 3                      Hobart  Inner Regional Australia
# 4                      Hobart  Inner Regional Australia
#
# [5 rows x 21 columns]

# %%
df_schools.columns
# Out:
# Index(['Calendar Year', 'ACARA SML ID', 'AGE ID', 'School Name', 'Suburb',
#        'State', 'Postcode', 'School Sector', 'School Type', 'Campus Type',
#        'Rolled Reporting Description', 'School URL', 'Governing Body',
#        'Governing Body URL', 'Year Range', 'Geolocation', 'ICSEA',
#        'Bottom SEA Quarter (%)', 'Lower Middle SEA Quarter (%)',
#        'Upper Middle SEA Quarter (%)', 'Top SEA Quarter (%)', 'Teaching Staff',
#        'Full Time Equivalent Teaching Staff', 'Non-Teaching Staff',
#        'Full Time Equivalent Non-Teaching Staff', 'Total Enrolments',
#        'Girls Enrolments', 'Boys Enrolments',
#        'Full Time Equivalent Enrolments', 'Indigenous Enrolments (%)',
#        'Language Background Other Than English (%)'],
#       dtype='object')

# %%
df_school_locs.columns
# Out:
# Index(['Calendar Year', 'ACARA SML ID', 'AGE ID', 'School Name', 'Suburb',
#        'State', 'Postcode', 'School Sector', 'School Type', 'Campus Type',
#        'Rolled Reporting Description', 'Latitude', 'Longitude',
#        'Statistical Area 1', 'Statistical Area 2',
#        'Name of Statistical Area 2', 'Statistical Area 3',
#        'Name of Statistical Area 3', 'Statistical Area 4',
#        'Name of Statistical Area 4', 'ABS Remoteness Area'],
#       dtype='object')

# %%
# Check Each Row Has A unique Identifier
print(df_schools.shape)
print(len(df_schools["ACARA SML ID"].unique()))
# Out:
# (9535, 31)
# 9535

# %%
print(df_school_locs.shape)
print(len(df_school_locs["ACARA SML ID"].unique()))
# Out:
# (10491, 21)
# 10491

# %%
# Join the Datasets Together To Create a Larger Set
# Left Join on School Profile

# First Get the Columns in the locations datafrane that are not also repersented in the school profile datafrane
# Easiest way to do this is to push the columsn name data into sets and run a difference
# However we will need to add the common key back in to join the data
set_prf_cols = set(df_schools.columns)
set_loc_cols = set(df_school_locs.columns)
extract_cols = list(set_loc_cols.difference(set_prf_cols))
extract_cols.sort()
extract_cols.insert(0, "ACARA SML ID")
extract_cols
# Out:
# ['ACARA SML ID',
#  'ABS Remoteness Area',
#  'Latitude',
#  'Longitude',
#  'Name of Statistical Area 2',
#  'Name of Statistical Area 3',
#  'Name of Statistical Area 4',
#  'Statistical Area 1',
#  'Statistical Area 2',
#  'Statistical Area 3',
#  'Statistical Area 4']

# %%
df_schools_merged = pd.merge(df_schools, df_school_locs[extract_cols], left_on="ACARA SML ID", right_on="ACARA SML ID", how="left")
df_schools_merged.head()
# Out:
#    Calendar Year  ACARA SML ID  AGE ID  \
# 0           2018         40000     3.0
# 1           2018         40001     4.0
# 2           2018         40002     5.0
# 3           2018         40003     7.0
# 4           2018         40004     9.0
#
#                                 School Name        Suburb State  Postcode  \
# 0            Corpus Christi Catholic School     Bellerive   TAS      7018
# 1                              Fahan School     Sandy Bay   TAS      7005
# 2                  Geneva Christian College       Latrobe   TAS      7307
# 3               Holy Rosary Catholic School     Claremont   TAS      7011
# 4  Immaculate Heart of Mary Catholic School  Lenah Valley   TAS      7008
#
#   School Sector School Type           Campus Type  ...  \
# 0      Catholic     Primary  School Single Entity  ...
# 1   Independent    Combined  School Single Entity  ...
# 2   Independent    Combined  School Single Entity  ...
# 3      Catholic     Primary  School Single Entity  ...
# 4      Catholic     Primary  School Single Entity  ...
#
#         ABS Remoteness Area   Latitude   Longitude  \
# 0  Inner Regional Australia -42.871256  147.371473
# 1  Inner Regional Australia -42.916158  147.352764
# 2  Outer Regional Australia -41.226741  146.438726
# 3  Inner Regional Australia -42.789375  147.248306
# 4  Inner Regional Australia -42.865543  147.290159
#
#     Name of Statistical Area 2 Name of Statistical Area 3  \
# 0            Bellerive - Rosny        Hobart - North East
# 1                    Sandy Bay               Hobart Inner
# 2                      Latrobe                  Devonport
# 3             Claremont (Tas.)        Hobart - North West
# 4  Lenah Valley - Mount Stuart               Hobart Inner
#
#   Name of Statistical Area 4  Statistical Area 1  Statistical Area 2  \
# 0                     Hobart             6100410               61004
# 1                     Hobart             6103105               61031
# 2        West and North West             6108720               61087
# 3                     Hobart             6101510               61015
# 4                     Hobart             6102812               61028
#
#    Statistical Area 3  Statistical Area 4
# 0               60102                 601
# 1               60105                 601
# 2               60402                 604
# 3               60103                 601
# 4               60105                 601
#
# [5 rows x 41 columns]

# %%
df_schools_nsw = df_schools_merged[df_schools_merged["State"]=="NSW"]
df_schools_nsw.head()
# Out:
#      Calendar Year  ACARA SML ID   AGE ID  \
# 228           2018         40275  28510.0
# 229           2018         40276   5298.0
# 230           2018         40277  26768.0
# 268           2018         40366   1409.0
# 269           2018         40367   1411.0
#
#                                School Name        Suburb State  Postcode  \
# 228    Saint Mary MacKillop College Albury       Jindera   NSW      2642
# 229                St Dominic Savio School      Rockdale   NSW      2216
# 230  Saint Mary MacKillop Colleges Limited   Wagga Wagga   NSW      2650
# 268                           Kinma School  Terrey Hills   NSW      2084
# 269                    Knox Grammar School     Wahroonga   NSW      2076
#
#     School Sector School Type           Campus Type  ...  \
# 228   Independent    Combined  School Single Entity  ...
# 229   Independent     Primary  School Single Entity  ...
# 230   Independent    Combined  School Single Entity  ...
# 268   Independent     Primary  School Single Entity  ...
# 269   Independent    Combined    School Head Campus  ...
#
#            ABS Remoteness Area   Latitude   Longitude  \
# 228   Inner Regional Australia -35.902879  146.826712
# 229  Major Cities of Australia -33.950985  151.149577
# 230   Inner Regional Australia -35.128967  147.347981
# 268  Major Cities of Australia -33.686607  151.216969
# 269  Major Cities of Australia -33.723114  151.119418
#
#        Name of Statistical Area 2 Name of Statistical Area 3  \
# 228                 Albury Region                     Albury
# 229            Rockdale - Banksia         Kogarah - Rockdale
# 230           Wagga Wagga - South                Wagga Wagga
# 268  Terrey Hills - Duffys Forest                  Warringah
# 269   Wahroonga (East) - Warrawee                Ku-ring-gai
#
#             Name of Statistical Area 4  Statistical Area 1  \
# 228                             Murray             1117503
# 229          Sydney - Inner South West             1138116
# 230                           Riverina             1126940
# 268          Sydney - Northern Beaches             1143210
# 269  Sydney - North Sydney and Hornsby             1141211
#
#      Statistical Area 2  Statistical Area 3  Statistical Area 4
# 228               11175               10901                 109
# 229               11381               11904                 119
# 230               11269               11303                 113
# 268               11432               12203                 122
# 269               11412               12103                 121
#
# [5 rows x 41 columns]

# %%
# Understand some of the data classifications
print(df_schools_nsw.shape)
print(df_schools_nsw["School Sector"].value_counts())
print(df_schools_nsw["School Type"].value_counts())
print(df_schools_nsw.shape)
# Out:
# (3155, 41)
# Government     2206
# Catholic        550
# Independent     399
# Name: School Sector, dtype: int64
# Primary      2093
# Secondary     544
# Combined      321
# Special       197
# Name: School Type, dtype: int64
# (3155, 41)

# %%
# Define A filter for Primary Schools or combined schools
primary_combined = df_schools_nsw["School Type"].isin(["Primary","Combined"])

# Define a filter for secular schools by excluding denominational 
secular = df_schools_nsw["School Sector"]!="Catholic"

#Apply the Filters
df_primary_secular_nsw=df_schools_nsw[primary_combined & secular]

df_primary_secular_nsw.head()
# Out:
#      Calendar Year  ACARA SML ID   AGE ID  \
# 228           2018         40275  28510.0
# 229           2018         40276   5298.0
# 230           2018         40277  26768.0
# 268           2018         40366   1409.0
# 269           2018         40367   1411.0
#
#                                School Name        Suburb State  Postcode  \
# 228    Saint Mary MacKillop College Albury       Jindera   NSW      2642
# 229                St Dominic Savio School      Rockdale   NSW      2216
# 230  Saint Mary MacKillop Colleges Limited   Wagga Wagga   NSW      2650
# 268                           Kinma School  Terrey Hills   NSW      2084
# 269                    Knox Grammar School     Wahroonga   NSW      2076
#
#     School Sector School Type           Campus Type  ...  \
# 228   Independent    Combined  School Single Entity  ...
# 229   Independent     Primary  School Single Entity  ...
# 230   Independent    Combined  School Single Entity  ...
# 268   Independent     Primary  School Single Entity  ...
# 269   Independent    Combined    School Head Campus  ...
#
#            ABS Remoteness Area   Latitude   Longitude  \
# 228   Inner Regional Australia -35.902879  146.826712
# 229  Major Cities of Australia -33.950985  151.149577
# 230   Inner Regional Australia -35.128967  147.347981
# 268  Major Cities of Australia -33.686607  151.216969
# 269  Major Cities of Australia -33.723114  151.119418
#
#        Name of Statistical Area 2 Name of Statistical Area 3  \
# 228                 Albury Region                     Albury
# 229            Rockdale - Banksia         Kogarah - Rockdale
# 230           Wagga Wagga - South                Wagga Wagga
# 268  Terrey Hills - Duffys Forest                  Warringah
# 269   Wahroonga (East) - Warrawee                Ku-ring-gai
#
#             Name of Statistical Area 4  Statistical Area 1  \
# 228                             Murray             1117503
# 229          Sydney - Inner South West             1138116
# 230                           Riverina             1126940
# 268          Sydney - Northern Beaches             1143210
# 269  Sydney - North Sydney and Hornsby             1141211
#
#      Statistical Area 2  Statistical Area 3  Statistical Area 4
# 228               11175               10901                 109
# 229               11381               11904                 119
# 230               11269               11303                 113
# 268               11432               12203                 122
# 269               11412               12103                 121
#
# [5 rows x 41 columns]

# %%
# Group the Data ro get some basic counts per postcode area
grp = df_primary_secular_nsw.groupby(["Name of Statistical Area 4","Name of Statistical Area 3", "Name of Statistical Area 2", "Postcode"])["Postcode"].count()
grp.reset_index(name="Count")
grp.sort_values(ascending=False, inplace=True)
grp.head(50)
# Out:
# Name of Statistical Area 4              Name of Statistical Area 3        Name of Statistical Area 2          Postcode
# Richmond - Tweed                        Richmond Valley - Hinterland      Lismore Region                      2480        21
# New England and North West              Armidale                          Armidale                            2350        11
# Sydney - Inner South West               Bankstown                         Greenacre - Mount Lewis             2190         9
# Richmond - Tweed                        Tweed Valley                      Murwillumbah Region                 2484         9
# Mid North Coast                         Taree - Gloucester                Taree                               2430         9
# Capital Region                          Goulburn - Mulwaree               Goulburn                            2580         8
# Coffs Harbour - Grafton                 Clarence Valley                   Grafton Region                      2460         8
# Richmond - Tweed                        Richmond Valley - Coastal         Mullumbimby                         2482         8
# Newcastle and Lake Macquarie            Lake Macquarie - West             Toronto - Awaba                     2283         8
# Capital Region                          South Coast                       Bega-Eden Hinterland                2550         8
# Sydney - Northern Beaches               Warringah                         Frenchs Forest - Belrose            2085         7
# Mid North Coast                         Kempsey - Nambucca                Kempsey                             2440         7
# Far West and Orana                      Broken Hill and Far West          Broken Hill                         2880         7
# Newcastle and Lake Macquarie            Lake Macquarie - East             Charlestown - Dudley                2290         7
# Richmond - Tweed                        Richmond Valley - Hinterland      Kyogle                              2474         7
# Central West                            Orange                            Orange                              2800         7
# Murray                                  Albury                            Albury Region                       2642         7
# Central West                            Orange                            Orange Region                       2800         7
# Sydney - Blacktown                      Mount Druitt                      Mount Druitt - Whalan               2770         7
# Sydney - Outer South West               Campbelltown (NSW)                Minto - St Andrews                  2566         7
# Hunter Valley exc Newcastle             Maitland                          Maitland - East                     2323         7
#                                         Lower Hunter                      Cessnock                            2325         7
# Mid North Coast                         Kempsey - Nambucca                Kempsey Region                      2440         6
# Sydney - Outer South West               Campbelltown (NSW)                Bradbury - Wedderburn               2560         6
# Illawarra                               Wollongong                        Balgownie - Fairy Meadow            2519         6
# Riverina                                Wagga Wagga                       Wagga Wagga Region                  2652         6
# Sydney - Blacktown                      Blacktown                         Lalor Park - Kings Langley          2147         6
# Hunter Valley exc Newcastle             Lower Hunter                      Cessnock Region                     2325         6
# Sydney - Outer West and Blue Mountains  Penrith                           Castlereagh - Cranebrook            2749         6
# Central West                            Bathurst                          Bathurst Region                     2795         6
# Far West and Orana                      Bourke - Cobar - Coonamble        Bourke - Brewarrina                 2840         6
# Sydney - Blacktown                      Mount Druitt                      Lethbridge Park - Tregear           2770         5
#                                         Blacktown - North                 Riverstone - Marsden Park           2765         5
#                                         Mount Druitt                      Bidwill - Hebersham - Emerton       2770         5
# Sydney - North Sydney and Hornsby       Ku-ring-gai                       Pymble                              2073         5
# Sydney - City and Inner South           Sydney Inner City                 Newtown - Camperdown - Darlington   2042         5
# Capital Region                          South Coast                       Bega - Tathra                       2550         5
# Sydney - Inner South West               Bankstown                         Panania - Milperra - Picnic Point   2213         5
#                                         Kogarah - Rockdale                Arncliffe - Bardwell Valley         2205         5
# Sydney - Inner West                     Strathfield - Burwood - Ashfield  Strathfield                         2135         5
# Sydney - Baulkham Hills and Hawkesbury  Hawkesbury                        Kurrajong Heights - Ebenezer        2758         5
# Sydney - North Sydney and Hornsby       North Sydney - Mosman             Mosman                              2088         5
# Sydney - Outer West and Blue Mountains  Blue Mountains                    Blaxland - Warrimoo - Lapstone      2774         5
# Sydney - Baulkham Hills and Hawkesbury  Rouse Hill - McGraths Hill        Rouse Hill - Beaumont Hills         2155         5
# Richmond - Tweed                        Richmond Valley - Hinterland      Casino Region                       2469         5
# Sydney - Baulkham Hills and Hawkesbury  Dural - Wisemans Ferry            Dural - Kenthurst - Wisemans Ferry  2158         5
# New England and North West              Tamworth - Gunnedah               Tamworth - North                    2340         5
# Far West and Orana                      Dubbo                             Dubbo - South                       2830         5
# Illawarra                               Dapto - Port Kembla               Unanderra - Mount Kembla            2526         5
#                                         Kiama - Shellharbour              Warilla                             2528         5
# Name: Postcode, dtype: int64

# %%
#Apply the Filters
postcodes = df_primary_secular_nsw["Postcode"].isin([2092,2093,2094,2095,2096,2097,2098,2099])
a = df_primary_secular_nsw[postcodes]
a.head()
# Out:
#      Calendar Year  ACARA SML ID   AGE ID                  School Name  \
# 499           2018         40845  28880.0     Karuna Montessori School
# 503           2018         40850  28974.0  Farmhouse Montessori School
# 731           2018         41197   7691.0       Seaforth Public School
# 740           2018         41206   7703.0        Dee Why Public School
# 751           2018         41217   7698.0        Harbord Public School
#
#               Suburb State  Postcode School Sector School Type  \
# 499       Narraweena   NSW      2099   Independent    Combined
# 503  North Balgowlah   NSW      2093   Independent    Combined
# 731         Seaforth   NSW      2092    Government     Primary
# 740          Dee Why   NSW      2099    Government     Primary
# 751       Freshwater   NSW      2096    Government     Primary
#
#               Campus Type  ...        ABS Remoteness Area   Latitude  \
# 499  School Single Entity  ...  Major Cities of Australia -33.747800
# 503    School Head Campus  ...  Major Cities of Australia -33.783352
# 731  School Single Entity  ...  Major Cities of Australia -33.793262
# 740  School Single Entity  ...  Major Cities of Australia -33.749025
# 751  School Single Entity  ...  Major Cities of Australia -33.772662
#
#       Longitude       Name of Statistical Area 2 Name of Statistical Area 3  \
# 499  151.276000         Beacon Hill - Narraweena                  Warringah
# 503  151.246409    Manly Vale - Allambie Heights                  Warringah
# 731  151.251235  Balgowlah - Clontarf - Seaforth                      Manly
# 740  151.285209        Dee Why - North Curl Curl                  Warringah
# 751  151.285790           Freshwater - Brookvale                  Warringah
#
#     Name of Statistical Area 4  Statistical Area 1  Statistical Area 2  \
# 499  Sydney - Northern Beaches             1142416               11424
# 503  Sydney - Northern Beaches             1143031               11430
# 731  Sydney - Northern Beaches             1141822               11418
# 740  Sydney - Northern Beaches             1142640               11426
# 751  Sydney - Northern Beaches             1142907               11429
#
#      Statistical Area 3  Statistical Area 4
# 499               12203                 122
# 503               12203                 122
# 731               12201                 122
# 740               12203                 122
# 751               12203                 122
#
# [5 rows x 41 columns]
